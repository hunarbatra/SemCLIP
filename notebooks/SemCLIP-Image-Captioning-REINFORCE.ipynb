# %% [markdown]
# # CLIP + REINFORCE based Image Captioning with Semantic Visual Tokens (SVT)

# %%
# %cd ..

# %%
# !pip install open_clip_torch peft accelerate open-clip-torch fire ipywidgets==8.1.2 jupyter_bbox_widget
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: open_clip_torch in /home/hb2546/.local/lib/python3.11/site-packages (2.24.0)
# Requirement already satisfied: peft in /home/hb2546/.local/lib/python3.11/site-packages (0.10.0)
# Requirement already satisfied: accelerate in /home/hb2546/.local/lib/python3.11/site-packages (0.29.3)
# Requirement already satisfied: fire in /home/hb2546/.local/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: ipywidgets==8.1.2 in /home/hb2546/.local/lib/python3.11/site-packages (8.1.2)
# Requirement already satisfied: jupyter_bbox_widget in /home/hb2546/.local/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: comm>=0.1.3 in /home/hb2546/.local/lib/python3.11/site-packages (from ipywidgets==8.1.2) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from ipywidgets==8.1.2) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from ipywidgets==8.1.2) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/hb2546/.local/lib/python3.11/site-packages (from ipywidgets==8.1.2) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/hb2546/.local/lib/python3.11/site-packages (from ipywidgets==8.1.2) (3.0.10)
# Requirement already satisfied: torch>=1.9.0 in /home/hb2546/.local/lib/python3.11/site-packages (from open_clip_torch) (2.3.0)
# Requirement already satisfied: torchvision in /home/hb2546/.local/lib/python3.11/site-packages (from open_clip_torch) (0.18.0)
# Requirement already satisfied: regex in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from open_clip_torch) (2023.10.3)
# Requirement already satisfied: ftfy in /home/hb2546/.local/lib/python3.11/site-packages (from open_clip_torch) (6.2.0)
# Requirement already satisfied: tqdm in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from open_clip_torch) (4.65.0)
# Requirement already satisfied: huggingface-hub in /home/hb2546/.local/lib/python3.11/site-packages (from open_clip_torch) (0.22.2)
# Requirement already satisfied: sentencepiece in /home/hb2546/.local/lib/python3.11/site-packages (from open_clip_torch) (0.2.0)
# Requirement already satisfied: protobuf in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from open_clip_torch) (3.20.3)
# Requirement already satisfied: timm in /home/hb2546/.local/lib/python3.11/site-packages (from open_clip_torch) (0.9.16)
# Requirement already satisfied: numpy>=1.17 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from peft) (23.1)
# Requirement already satisfied: psutil in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from peft) (5.9.0)
# Requirement already satisfied: pyyaml in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from peft) (6.0.1)
# Requirement already satisfied: transformers in /home/hb2546/.local/lib/python3.11/site-packages (from peft) (4.40.1)
# Requirement already satisfied: safetensors in /home/hb2546/.local/lib/python3.11/site-packages (from peft) (0.4.3)
# Requirement already satisfied: six in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from fire) (1.16.0)
# Requirement already satisfied: termcolor in /home/hb2546/.local/lib/python3.11/site-packages (from fire) (2.4.0)
# Requirement already satisfied: filelock in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from huggingface-hub->open_clip_torch) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from huggingface-hub->open_clip_torch) (2023.10.0)
# Requirement already satisfied: requests in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from huggingface-hub->open_clip_torch) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from huggingface-hub->open_clip_torch) (4.9.0)
# Requirement already satisfied: decorator in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (2.15.1)
# Requirement already satisfied: stack-data in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets==8.1.2) (4.8.0)
# Requirement already satisfied: sympy in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (1.12)
# Requirement already satisfied: networkx in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (3.1)
# Requirement already satisfied: jinja2 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /home/hb2546/.local/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/hb2546/.local/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9.0->open_clip_torch) (12.4.127)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /home/hb2546/.local/lib/python3.11/site-packages (from ftfy->open_clip_torch) (0.2.13)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from torchvision->open_clip_torch) (10.2.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/hb2546/.local/lib/python3.11/site-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.2) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.2) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from jinja2->torch>=1.9.0->open_clip_torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from requests->huggingface-hub->open_clip_torch) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/hb2546/.local/lib/python3.11/site-packages (from requests->huggingface-hub->open_clip_torch) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from requests->huggingface-hub->open_clip_torch) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hb2546/.local/lib/python3.11/site-packages (from requests->huggingface-hub->open_clip_torch) (2023.7.22)
# Requirement already satisfied: executing in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.2) (0.8.3)
# Requirement already satisfied: asttokens in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.2) (2.0.5)
# Requirement already satisfied: pure-eval in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.2) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /share/apps/anaconda3/2024.02/lib/python3.11/site-packages (from sympy->torch>=1.9.0->open_clip_torch) (1.3.0)

# %%
import textwrap

import open_clip
import peft

from PIL import Image
from transformers import AutoModelForCausalLM, AutoTokenizer

import torch

from torch import optim
from torch.nn import functional as F
from tqdm.auto import tqdm

from SemCLIP.semclip import get_segments_embeddings

# %%
print = tqdm.external_write_mode()(print)

def endless_range(start=0, step=1):
    """An endless range generator."""
    i = start
    while True:
        yield i
        i += step

def logp_completion(logits, tokens, mask):
    """Compute the log probabilities of completions given their prompts.

    Args:
        tokens: The tokens input to the model. Shape: (..., T).
        logits: The logits output from the model. Shape: (..., T, V).
        mask: A mask indicating which tokens should be included in the log probabilities. It should
            exclude prompt tokens and padding tokens. Shape: (..., T).

    Returns:
        The log probabilities of the completions given their prompts. Shape: (...).
    """
    logits = F.log_softmax(logits, dim=-1)
    logp_tokens = logits[..., :-1, :].gather(-1, tokens[..., 1:, None])[..., 0]
    return torch.sum(logp_tokens * mask[..., 1:], dim=-1)

# %%
prompt = "The theme of this image is" 
prompt = "What do you see in this picture?"
length = 80
batch_size = 64 
kl_weight = 4e-3
temperature = 0.8

# %%
clip_name = "ViT-L-14-336"
clip_pretrained = "openai"
# model_name = "EleutherAI/pythia-160m-deduped"
# model_name = "mistralai/Mistral-7B-v0.1"
# model_name = "meta-llama/Llama-2-7b-hf"
model_name = "microsoft/phi-2"
device = torch.device("cuda:0")

# %%
# Load CLIP
# # clip_tokenizer = open_clip.get_tokenizer(clip_name)
# clip_model, _, clip_preprocess = open_clip.create_model_and_transforms(
#     clip_name, pretrained=clip_pretrained, device=device
# )
# clip_model.eval().requires_grad_(False)

# Load language model
tokenizer = AutoTokenizer.from_pretrained(model_name, token='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')
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    # device_map={"": device}
    token='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',
    trust_remote_code=True # for phi-2
)

# Move the model to the GPU
model = model.to(device)

# Prepare LoRA
peft_config = peft.LoraConfig(
    peft.TaskType.CAUSAL_LM,
    inference_mode=False,
    r=32,
    lora_alpha=8,
    lora_dropout=0.0,
    target_modules=[
        # For NeoX and Pythia
        # "attention.query_key_value",
        # "attention.dense",
        # "mlp.dense_h_to_4h",
        # "mlp.dense_4h_to_h",
        # For Llama and Mistral 7B
        # "self_attn.q_proj",
        # "self_attn.k_proj",
        # "self_attn.v_proj",
        # "self_attn.o_proj",
        # "mlp.gate_proj",
        # "mlp.up_proj",
        # "mlp.down_proj",
        # For Phi:
        'Wqkv',
        'fc1',
        'fc2',
    ],
)
model = peft.get_peft_model(model, peft_config)

# Finish preparing model
model.gradient_checkpointing_enable()
model.enable_input_require_grads()
model.train()
model.print_trainable_parameters()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# trainable params: 26,214,400 || all params: 2,805,898,240 || trainable%: 0.9342605382581515

# %% [markdown]
# ### Optimize the LLM with REINFORCE

# %%
import open_clip

import torch
from torchvision.transforms import Compose, Resize, ToTensor, Normalize
from PIL import Image


# Assuming the CLIP model is loaded as shown in the reference code provided
clip_model, _, preprocess = open_clip.create_model_and_transforms(
    clip_name, pretrained=clip_pretrained, device=device
)

clip_tokenizer = open_clip.get_tokenizer(clip_name)

# %%
added_embeddings_tensor = get_segments_embeddings(image_name='dog.jpeg', data_name='test_images', projection_dim=768)

# %%
added_embeddings_tensor = added_embeddings_tensor.to(device)

print(added_embeddings_tensor.shape)
print(added_embeddings_tensor)
# Out:
# torch.Size([1, 768])
# tensor([[ 5.0610e-01,  3.0874e-01,  2.2853e-01, -2.6581e-01, -3.1092e-01,
#           1.6562e-01, -7.2087e-02, -6.4041e-02,  3.6988e-01, -2.8280e-01,
#          -1.7887e-01, -9.9637e-02,  5.3308e-02, -5.8022e-01,  6.6427e-02,
#           8.0651e-02,  4.9946e-02,  1.8755e-01,  2.6872e-01, -1.2413e-01,
#           1.0862e-02,  2.1680e-01, -4.6288e-01, -8.6663e-02,  4.9156e-01,
#           7.9659e-01, -3.6737e-01,  4.6936e-01,  3.6757e-01,  1.0165e+00,
#           3.1140e-01,  6.7719e-01, -9.3775e-02,  1.0950e+00, -2.5884e-02,
#          -4.2328e-01, -8.3998e-01, -2.8377e-01,  1.1994e-02, -8.0993e-01,
#          -3.2794e-01,  6.1093e-01,  2.8080e-01,  1.1519e-01,  2.5315e-01,
#          -8.9761e-03,  1.2594e-01, -1.8304e-01,  1.9305e-01,  3.7651e-01,
#          -3.1843e-01, -2.0094e-01,  6.0299e-01, -1.5161e-01,  7.1777e-01,
#          -2.1114e-01, -6.3804e-02,  6.7453e-01,  2.6493e-01,  2.4697e-01,
#          -4.3676e-01, -5.1152e-01,  8.4315e-01,  2.9186e-01, -2.7764e-01,
#           2.3009e-01, -5.5720e-02, -3.7870e-01, -2.3988e-01, -4.1370e-01,
#          -7.4128e-01, -3.2719e-01,  3.9716e-01, -9.2266e-02, -1.3119e-01,
#           6.1651e-01, -1.9004e-01,  1.1225e-01, -4.6839e-01,  2.3415e-01,
#           3.8012e-01,  1.6453e-01,  8.5480e-01, -1.2561e-01,  8.9788e-01,
#           4.9282e-01,  3.3667e-01, -6.6862e-03, -1.3302e-01,  1.7211e-01,
#          -2.1085e-01, -5.1129e-01, -6.7177e-01, -3.8591e-01,  3.0098e-01,
#           2.4225e-01,  9.3840e-01, -5.1309e-01,  3.5341e-01, -3.0680e-01,
#          -7.6577e-03,  3.9650e-01, -2.2280e-01,  1.7867e-01,  7.9153e-01,
#           3.2122e-01, -9.5124e-02,  7.0932e-01, -2.7856e-01,  2.9425e-01,
#           2.4798e-01,  7.6579e-02, -4.8932e-01,  4.7617e-01, -1.8201e-01,
#           3.7090e-01, -4.0172e-01,  5.4614e-01,  8.2175e-01,  1.7431e-01,
#           7.2720e-01, -1.0251e+00,  1.1707e+00, -1.2448e-01, -3.9995e-01,
#          -5.9104e-01,  4.4599e-01, -7.4912e-02,  3.5948e-02,  3.1410e-01,
#          -6.3418e-01,  6.3678e-01,  2.1800e-01, -1.0662e-01,  6.3496e-01,
#           5.8505e-01,  2.5664e-01,  8.2694e-01,  2.8925e-01,  1.9056e-01,
#          -1.3422e+00, -4.8218e-01,  2.7524e-01,  9.0222e-02,  1.5930e+00,
#           3.3673e-01,  3.2744e-01,  9.4736e-02, -4.0282e-01,  3.5107e-01,
#           4.4265e-01,  1.1187e-01,  6.3424e-01,  1.1466e-01,  4.3845e-01,
#           4.4838e-01,  4.0478e-01,  3.1391e-01, -5.1969e-01, -4.4897e-02,
#          -6.2260e-01,  2.5948e-01, -3.3618e-01, -2.1626e-01, -1.9245e-01,
#          -9.0761e-02, -1.3513e+00, -5.7272e-01,  7.3228e-01,  2.1178e-01,
#           3.2413e-01, -3.5927e-01,  9.4281e-01, -2.8756e-01, -3.8531e-01,
#          -1.6301e-01,  7.8175e-02,  1.9212e-01,  3.8041e-02,  7.1502e-01,
#           2.7755e-01,  3.2349e-01,  1.3817e-01, -3.2756e-01, -4.5290e-01,
#           5.1561e-01, -5.2396e-01, -7.8151e-01, -2.7497e-01, -6.5618e-01,
#           8.3538e-01,  7.9577e-02, -7.9548e-01, -3.7295e-01, -6.2781e-01,
#           6.3432e-01, -2.5123e-01,  1.5200e-01,  5.4060e-02,  3.3593e-01,
#          -5.3595e-01, -3.0199e-02, -7.2832e-02, -3.1781e-01, -9.7615e-01,
#          -4.3840e-01,  3.0300e-01, -1.2756e-01, -3.8278e-01,  1.4042e-01,
#           6.1280e-02, -8.1723e-01, -5.8278e-02,  1.3647e-01,  9.6969e-01,
#           9.5657e-02, -9.1423e-01, -3.5392e-01, -1.6018e-01,  3.3088e-01,
#          -4.5847e-01, -3.7245e-01, -1.3608e-01,  2.5282e-01, -5.1780e-01,
#           5.0347e-01, -6.1341e-01,  2.9835e-01, -2.8021e-01,  2.9363e-01,
#           8.3285e-01,  3.6034e-01,  1.1736e-01, -3.6889e-01, -5.6923e-02,
#           7.3354e-01, -1.9900e-01, -5.0590e-01, -3.8934e-01,  2.3385e-01,
#          -6.6214e-02,  6.2054e-01, -5.9715e-01, -8.4100e-03,  5.2184e-02,
#           1.7306e-01, -5.4683e-01, -3.6543e-01,  9.4508e-03,  6.5447e-01,
#          -2.8968e-01,  7.7867e-02, -6.3529e-02,  2.6409e-01, -4.8506e-01,
#           8.4044e-02,  1.3641e+00,  6.1395e-01, -2.7867e-01,  7.0529e-02,
#           5.7126e-01,  3.4997e-01, -5.3889e-01,  5.6793e-01, -2.6569e-01,
#          -6.4396e-01, -1.8345e-01,  2.3688e-01,  3.7837e-01,  6.7762e-02,
#           7.7213e-02, -5.4093e-02,  7.0904e-01, -1.1091e-01,  2.7938e-01,
#           1.1609e+00,  3.7283e-01,  3.1704e-01, -5.6468e-02,  4.2942e-01,
#           4.9669e-01, -3.3340e-01,  6.3860e-01,  2.8389e-01,  4.7830e-02,
#           4.8291e-01,  4.6156e-01,  4.3972e-01, -6.2013e-01, -2.0387e-01,
#          -2.2014e-01,  2.4208e-01, -4.6116e-01,  5.7385e-01,  1.3836e-01,
#           1.4447e-01, -9.7811e-02,  6.7910e-01,  6.0402e-01, -8.1690e-02,
#          -1.0050e+00,  3.8145e-02, -6.3510e-01, -9.3671e-01,  7.8381e-01,
#           1.0184e+00, -1.9629e-01, -2.0244e-01,  9.0996e-01, -5.6620e-01,
#          -4.4465e-01, -6.3927e-02, -1.0874e+00, -1.9797e-01,  2.8113e-01,
#           2.5528e-01, -3.8773e-01, -2.9153e-01, -3.3932e-02,  3.4468e-01,
#           8.0787e-01, -6.0798e-01,  7.6584e-04, -2.4705e-01, -2.2375e-01,
#           3.2227e-01, -3.9128e-01, -3.2289e-02,  2.5892e-01, -5.3819e-01,
#           2.5383e-01, -7.1564e-01, -1.2537e-01,  4.1585e-01,  2.3043e-01,
#           1.2555e-01, -4.4645e-01, -4.3533e-01,  7.1764e-01,  4.4597e-01,
#           1.4318e-01, -7.3933e-01, -7.8445e-01,  2.9488e-01, -6.1312e-01,
#           1.6623e+00,  4.0890e-01,  1.4262e-01,  5.5178e-01,  5.7420e-01,
#          -6.7429e-01, -7.6301e-01, -5.5753e-01, -1.7210e-01,  3.4255e-01,
#           7.6423e-01,  4.4546e-01, -9.6044e-01, -1.0153e-01,  1.2530e-02,
#           4.7385e-01, -4.8059e-01,  3.2824e-01, -3.4995e-01, -4.5978e-01,
#          -4.3033e-01,  1.2263e-01,  3.0836e-03, -1.4713e-01, -4.4183e-01,
#          -1.2979e-01,  8.9494e-02,  3.8402e-01, -2.7031e-01,  5.9788e-01,
#          -1.8755e-01, -9.9668e-01,  1.0190e+00,  1.9396e-01,  1.1028e+00,
#           9.2673e-01,  7.1512e-01, -3.3162e-01, -8.4429e-01,  1.8356e-01,
#           7.2984e-01, -2.8124e-01,  5.9379e-01,  1.6363e-01,  2.8054e-01,
#          -6.9610e-01, -4.3497e-02,  1.2240e-01, -1.7736e-01, -3.9017e-01,
#          -3.1573e-01,  3.4272e-01,  3.9741e-01, -5.5678e-01, -6.2937e-02,
#          -1.3876e-02,  6.7705e-03, -1.2715e+00, -1.3259e-01, -1.0162e+00,
#           3.9204e-01,  1.2068e-01, -8.2520e-01, -1.1751e-01, -3.4667e-01,
#           4.9472e-01, -5.0293e-01, -3.4583e-01,  4.6385e-01,  1.0087e+00,
#           3.7655e-02, -4.3970e-01,  4.6526e-01,  2.0454e-02, -1.4730e-01,
#          -2.2095e-01, -4.1989e-01,  1.8175e-01, -4.8086e-01, -5.6217e-01,
#          -2.0849e-02, -5.1183e-01, -2.9843e-01, -2.9669e-01,  2.9725e-01,
#          -3.0858e-01,  4.7523e-02, -3.3289e-01, -3.3719e-01, -5.0140e-01,
#           6.9926e-01,  4.1210e-01, -3.5665e-01, -8.2890e-01, -3.7146e-01,
#           2.0824e-01, -1.8946e-01,  4.3853e-01, -3.8716e-01,  2.4719e-03,
#           7.6052e-01,  4.9163e-01,  3.5032e-01,  6.1986e-01,  2.8251e-01,
#          -1.2961e-01, -1.5299e-01,  4.9118e-01,  1.7346e-01, -1.7869e-01,
#           7.1024e-01,  6.8113e-02, -4.5477e-01,  3.7330e-01, -2.6445e-01,
#           3.0898e-01,  4.9512e-01, -4.3794e-02,  3.4132e-01, -3.8880e-01,
#          -1.5456e-01, -5.9504e-01, -3.9031e-01,  3.3025e-01, -2.0529e-01,
#          -8.4962e-01,  3.0800e-02, -2.7732e-01, -5.5292e-01,  1.7290e-01,
#           1.3675e-01,  3.8009e-01, -2.5859e-01,  1.0792e-01, -9.1808e-01,
#          -5.4003e-02,  1.2394e-01,  5.5014e-02, -7.0062e-02, -4.0604e-02,
#          -6.0183e-01, -3.4420e-02, -6.1170e-01, -1.3101e-01, -6.5005e-01,
#          -6.6674e-01,  6.1228e-02,  7.5486e-01, -6.1238e-01, -5.5151e-01,
#          -9.6844e-02, -2.3035e-01, -2.9851e-02,  3.3447e-01,  5.9396e-01,
#          -8.6349e-02, -3.4868e-01, -4.1501e-01, -6.0597e-01,  9.3018e-01,
#           1.6790e-02,  2.2623e-01, -4.4568e-01, -1.6696e-01,  5.2131e-01,
#           4.0176e-03, -5.5126e-02, -7.9432e-01,  1.9826e-01,  1.6530e-01,
#          -9.1190e-01,  5.3103e-02, -5.7187e-01,  3.1356e-01, -4.1042e-01,
#           1.4746e-01,  7.6275e-01, -6.5796e-01,  4.4766e-01,  8.2902e-01,
#          -3.9967e-01, -2.8418e-02, -2.3920e-01, -7.8242e-01, -6.4571e-01,
#          -6.3524e-01,  3.2228e-01,  2.0364e-01, -2.9612e-01, -5.4414e-01,
#           5.0233e-01, -2.2803e-01, -8.4076e-01, -2.8159e-01,  3.3930e-01,
#           2.6818e-01,  6.0046e-01, -2.8537e-02,  1.4491e-01,  3.7152e-02,
#          -3.8911e-01,  4.9785e-01,  3.6510e-02, -2.9650e-01, -3.8330e-01,
#          -3.3895e-01,  2.1046e-01, -2.8720e-01, -2.1016e-01,  1.2640e-01,
#          -6.5108e-02,  1.3029e-01,  7.7929e-01, -2.3416e-01, -4.8388e-02,
#           1.5946e-01, -7.2996e-01, -1.6624e-01, -5.7388e-01, -3.3850e-01,
#          -1.1681e+00,  7.4455e-01, -5.4336e-01,  5.2057e-01,  1.4712e-03,
#           1.8978e-01,  1.0676e+00, -2.5102e-01, -2.7094e-01,  5.8966e-01,
#          -4.9748e-01,  1.1369e+00,  5.1195e-01, -4.1944e-01,  2.1492e-01,
#          -2.7500e-01, -4.2355e-01,  7.6293e-01, -3.6492e-01,  4.8900e-01,
#           6.6970e-01,  9.8435e-01, -4.3255e-01,  4.8050e-01,  3.5427e-01,
#           4.9674e-01, -4.6384e-01,  6.8831e-01, -3.9028e-01, -6.8628e-01,
#          -3.1677e-01,  7.0411e-01, -7.2016e-01, -9.8679e-01, -5.2355e-01,
#          -4.1640e-01, -5.4067e-01,  4.7228e-01,  4.7669e-02,  5.6649e-01,
#           7.4316e-02, -4.1911e-02,  7.5491e-02, -1.1011e-01, -5.3318e-01,
#           4.4077e-01, -3.9772e-01,  1.1206e-01,  6.5062e-01, -5.3325e-02,
#           3.4985e-01,  5.9235e-01,  2.8996e-02,  3.5535e-01, -9.3895e-01,
#           3.6237e-01, -4.7673e-01, -6.3511e-01, -1.0885e+00, -1.2598e-01,
#          -1.3766e-01, -2.6562e-01,  3.4600e-01,  5.3511e-01, -4.3505e-01,
#          -6.0488e-01,  7.8252e-02,  7.6684e-01,  3.5054e-01,  7.4371e-02,
#          -5.0499e-01, -7.0592e-01,  5.1971e-01,  5.5225e-01,  8.7113e-01,
#           6.9520e-02,  5.4190e-01,  9.5006e-02,  6.1877e-01,  4.4848e-01,
#           2.3384e-01, -3.6197e-01,  5.6521e-01, -1.4670e-01, -3.0795e-01,
#          -1.1453e+00, -7.9316e-01,  2.0755e-01,  2.6365e-01,  6.1632e-01,
#           2.6842e-01, -3.2240e-01, -3.5429e-01, -9.9322e-02,  4.7707e-01,
#          -1.5291e-01,  5.3418e-01,  5.7003e-02, -4.4185e-01, -2.6650e-01,
#          -2.3215e-01, -5.0307e-01, -8.9048e-01,  1.9974e-01,  4.2036e-02,
#          -6.5387e-01,  3.4377e-01, -3.6070e-01, -3.1353e-01,  3.0053e-01,
#          -2.6592e-01,  3.7062e-01,  7.4471e-01, -3.3134e-02,  1.6990e-01,
#          -2.8192e-01, -1.1170e+00, -5.5807e-01, -1.6187e-01,  2.4832e-01,
#           8.7168e-01, -1.1304e-01, -1.5988e-01,  4.0519e-01, -1.8662e-01,
#           3.1210e-03, -5.4375e-01, -2.8873e-01, -2.8643e-01, -8.6804e-02,
#          -2.3292e-01,  2.1809e-01, -5.6041e-01, -3.5044e-02,  2.9971e-01,
#          -3.8021e-01, -5.6376e-01, -9.9411e-02, -5.7043e-02,  2.2279e-02,
#          -1.8629e-01,  3.8441e-01, -5.1392e-01,  7.1430e-01, -4.2694e-01,
#          -3.6792e-01, -4.6755e-01,  1.0151e-01, -3.3578e-01, -3.7102e-01,
#           1.9720e-01,  3.6198e-01,  6.3995e-01,  2.4125e-01, -3.6266e-01,
#           8.6483e-01, -4.7485e-01, -3.5324e-01,  7.4750e-01, -2.5639e-01,
#          -1.8019e-01, -6.5429e-01, -7.9678e-02, -4.0421e-02, -3.1659e-01,
#           2.2390e-01, -3.8951e-02, -4.9992e-01, -3.2205e-01,  4.6202e-01,
#          -1.3956e+00, -8.1707e-02,  6.0742e-01, -1.7576e-01,  7.6237e-01,
#          -1.8113e-01, -9.8239e-02,  1.0396e-01, -7.3102e-01, -8.2610e-01,
#           5.0848e-01,  2.5067e-01, -9.6556e-01,  9.4408e-01,  1.6842e-01,
#          -1.9981e-01,  9.9897e-02,  4.4741e-01, -1.0519e+00,  3.8345e-02,
#          -6.3864e-01,  4.4081e-01, -4.1741e-02, -6.9783e-01, -1.2980e-01,
#          -1.3281e-01, -7.0069e-03,  2.9576e-01, -4.9768e-01, -2.1086e-01,
#          -6.8583e-01,  6.5623e-01,  3.7378e-01]], device='cuda:0')

# %%
# torch.save(added_embeddings_tensor, 'added_embeddings_tensor.pt')

# torch.load('added_embeddings_tensor.pt')

# %%
# Settings
torch.set_float32_matmul_precision("high")

added_embeddings_tensor = added_embeddings_tensor.to(device)

# Prepare the prompt
inputs = tokenizer([prompt] * batch_size, return_tensors="pt").to(device)
input_len = inputs.input_ids.shape[1]
logp_mask = torch.tensor(
    [[False] * input_len + [True] * length] * batch_size, device=device
)

# Optimize the LLM
opt = optim.AdamW(model.parameters(), lr=1e-4, betas=(0.9, 0.95))

try:
    for i in tqdm(endless_range()):
        # Generate a batch of samples from the model
        model.eval()
        tokens = model.generate(
            inputs.input_ids,
            attention_mask=inputs.attention_mask,
            do_sample=True,
            min_new_tokens=length,
            max_new_tokens=length,
            pad_token_id=tokenizer.eos_token_id,
            temperature=temperature,
            top_k=0,
        )

        # Get the logits of the samples from the model and the reference model
        attention_mask = torch.cat(
            (inputs.attention_mask, torch.ones_like(tokens[:, input_len:])), dim=1
        )
        with torch.no_grad(), model.disable_adapter():
            outputs_ref = model(tokens, attention_mask=attention_mask, use_cache=False)
        model.train()
        outputs = model(tokens, attention_mask=attention_mask, use_cache=False)

        # Compute the log probability of the samples under the model and the reference model
        logp = logp_completion(outputs.logits / temperature, tokens, logp_mask)
        logp_ref = logp_completion(outputs_ref.logits / temperature, tokens, logp_mask)

        # Compute the CLIP loss
        texts = [tokenizer.decode(t, skip_special_tokens=True) for t in tokens]
        # print(tokens)
        clip_tokens = clip_tokenizer(texts).to(device)
        with torch.cuda.amp.autocast():
            text_embeds = clip_model.encode_text(clip_tokens).float()
        cost_clip = torch.cosine_similarity(text_embeds, added_embeddings_tensor, dim=-1).arccos()

        # Compute the KL penalty
        cost_kl = logp.detach() - logp_ref

        # REINFORCE
        cost = cost_clip + kl_weight * cost_kl
        baseline = (cost.sum() - cost) / (cost.numel() - 1)
        box = torch.exp(logp - logp.detach())
        loss = torch.mean(box * cost + (1 - box) * baseline)

        # Update the model
        opt.zero_grad()
        loss.backward()
        opt.step()

        # Print statistics and the best sample in the batch
        grad_norm = torch.cat(
            [p.grad.flatten() for p in model.parameters() if p.grad is not None]
        ).norm()

        print(
            f"step: {i}, loss: {loss.item():g}, clip: {cost_clip.mean().item():g}, kl: {cost_kl.mean().item():g}, grad: {grad_norm.item():g}"
        )
        best_text = texts[torch.argmin(cost).item()]
        print(textwrap.fill(best_text, width=80))
        print()

except KeyboardInterrupt:
    pass
# Out:
# 0it [00:00, ?it/s]
# step: 0, loss: 1.50796, clip: 1.52056, kl: -3.14999, grad: 0.0243376
# What do you see in this picture? I see a vase of flowers, a bowl of fruit, and a
# plate of cookies. I decide to make a story based on this picture.  Once upon a
# time, there was a girl named Lily who loved flowers. She had a beautiful vase of
# flowers on her table, and she liked to arrange them every day. She also had a
# bowl of fruit and a plate of cookies
#
# step: 1, loss: 1.50926, clip: 1.51892, kl: -2.41535, grad: 0.0230939
# What do you see in this picture? A) A family of deer B) A piccolo concerto C) A
# beautiful mountain D) A group of friends playing soccer  Answer: B) A piccolo
# concerto  Great job! Now, let's see if you can apply this knowledge to real life
# situations.  3) Your friend tells you they want to learn how to play the piccolo
#
# step: 2, loss: 1.50703, clip: 1.51938, kl: -3.08827, grad: 0.0235732
# What do you see in this picture? Animal, fruit, vegetable, star, or flower?" The
# mother and child looked at the picture and the mother pointed to the items. The
# child repeated the words and then pointed to the items. The mother praised the
# child and gave them a hug. AI: The main idea of the paragraph is that the mother
# is teaching her baby some words using flashcards and pictures. The supporting
# details are the
#
# step: 3, loss: 1.50567, clip: 1.51773, kl: -3.01358, grad: 0.0289429
# What do you see in this picture? You might notice that there are two circles in
# the center of the painting, and that they appear to be the same size and shape.
# These circles are an example of symmetry. The painting is symmetrical because
# the two circles are mirror images of each other. The same is true for the other
# elements in the painting, such as the trees, the clouds, and the horizon line.
# Another example
#
# step: 4, loss: 1.50692, clip: 1.51832, kl: -2.85102, grad: 0.0226818
# What do you see in this picture? How many colors do you see? What shapes do you
# see? What lines do you see?  -Which color do you like the most? Which color do
# you like the least? Why do you like or dislike these colors?  -Why do you think
# the artist chose to use different textures in this painting? How does this
# texture affect the mood of the painting?  -What
#
# step: 5, loss: 1.50292, clip: 1.51428, kl: -2.83915, grad: 0.0216312
# What do you see in this picture? What colors do you notice? Can you see any
# shapes?"  2. "When you go outside, what sounds do you hear? Can you identify the
# different sounds?"  3. "Try to touch different textures with your hands. What do
# they feel like? How are they different from each other?"  4. "Listen to a piece
# of music. What emotions do you feel
#
# step: 6, loss: 1.50101, clip: 1.512, kl: -2.74694, grad: 0.0304477
# What do you see in this picture? A cat, a dog, or a squirrel?"  In the first
# picture, she showed the children that the cat was the subject because it was the
# one doing the action, walking around the house. In the second picture, the dog
# was the subject because it was the one barking and chasing the squirrel. And in
# the third picture, the squirrel was the subject because it was the one being
# chased
#
# step: 7, loss: 1.50205, clip: 1.51265, kl: -2.64998, grad: 0.0232762
# What do you see in this picture? What colors do you see? What shapes do you see?
# How do these elements come together to create a balanced and harmonious
# composition?  Answer:  In this picture, you might see a bowl of fruit on a
# table. The colors could be bright and vibrant, with shades of red, orange, and
# yellow. The shapes might be organic, with curved lines and uneven surfaces.
# These
#
# step: 8, loss: 1.50235, clip: 1.51528, kl: -3.23111, grad: 0.0274016
# What do you see in this picture? I see a picture of a cat.  Exercise 3:  What
# are some events that happen on a daily, weekly, and monthly basis?  Answer 3:
# Daily events include waking up, eating, going to school, and going to bed.
# Weekly events include going to church on Sundays or attending other religious
# services. Monthly events include birthdays, holidays, and other special
# occasions
#
# step: 9, loss: 1.50117, clip: 1.51394, kl: -3.19463, grad: 0.0346164
# What do you see in this picture? Look for the black and white cat sitting on the
# red chair."   2. "Listen to this sentence and tell me what it means: 'The cat in
# the hat.'"   3. "Take a look at this word and tell me which letter makes the
# sound /b/: cat."   4. "Pick out all the colors in this picture: green apple
#
# step: 10, loss: 1.50453, clip: 1.51569, kl: -2.79097, grad: 0.0411834
# What do you see in this picture? What is happening?"  The children looked at the
# picture and started to discuss what they saw. Some said they saw a cat in a
# tree, while others said they saw a dog chasing a ball.  "Well, it's actually a
# picture of a bird," the parent explained patiently. "Do you notice the feathers
# and wings?"  The children looked closer and realized they had missed
#
# step: 11, loss: 1.50633, clip: 1.5173, kl: -2.74132, grad: 0.0424725
# What do you see in this picture?'') or "Whom do you know?" allows you to learn
# about the ways in which the other person has been exposed to the culture and has
# prepared for a meeting. People often know whom to call, what to say, and how to
# behave. #* Answering these questions helps the interviewer understand how the
# other person has prepared for the interview and gives you the opportunity to
# find out
#
# step: 12, loss: 1.50532, clip: 1.51572, kl: -2.60149, grad: 0.0355346
# What do you see in this picture? Describe what you see and your feelings about
# the picture. You can draw a picture, write a sentence, or use any other form of
# communication. There is no wrong answer, as long as you express your thoughts
# and feelings honestly and respectfully.  Example:  Picture: A picture of an
# alien family sitting together and sharing a meal.  I see a happy alien family
# sitting together
#
# step: 13, loss: 1.50314, clip: 1.51538, kl: -3.06114, grad: 0.0354209
# What do you see in this picture? This is an example of a real image. The image
# is formed on the film when the rays of light are reflected by the lens and
# converge at a point.  Real images are formed when the rays of light are real,
# meaning that they actually come from a point. They are inverted, meaning that
# the left and right sides are reversed. They are also located behind the lens,
# beyond the focal
#
# step: 14, loss: 1.50555, clip: 1.51496, kl: -2.35336, grad: 0.0560529
# What do you see in this picture? Who is in it? Where are they? What are they
# doing? How do you know? Write down the name of the person or thing that you see,
# and the word that you use to name it. For example, you might write: banana,
# yellow,". - Ask questions: "What do you wonder or question about the picture?
# What do you want to know more about or learn
#
# step: 15, loss: 1.5039, clip: 1.51378, kl: -2.46992, grad: 0.0488072
# What do you see in this picture? It's a tree," Mary said. "Now, let's ask each
# other some questions."  "How many leaves does the tree have?" John asked.  "I
# see about ten leaves," Mary replied.  "What color are the leaves?" Sarah asked.
# "They're green," Mary said.  "And what time of year do you think this picture
#
# step: 16, loss: 1.50835, clip: 1.51638, kl: -2.00665, grad: 0.050442
# What do you see in this picture? What can you infer about the figure in the
# center? How does the use of light and shadow contribute to the overall effect?
# Answer: The picture could be a self-portrait, a still life, or a landscape,
# depending on the context. The figure in the center could be a person, a group of
# people, or an animal. The use of light and shadow can create a
#
# step: 17, loss: 1.50151, clip: 1.51276, kl: -2.81262, grad: 0.0522645
# What do you see in this picture? Is it a house, a tree, or a cat? You can't
# really tell without all the details, right? But some people can. What if I told
# you that this picture is actually a picture of a secret code? It's like a puzzle
# that only certain people can solve.  That's exactly what the painter, Joan Miró,
# did in his painting called "Multiplication
#
# step: 18, loss: 1.50224, clip: 1.51473, kl: -3.12128, grad: 0.0615636
# What do you see in this picture? What do you think is happening?"  The child
# looked closely at the picture and then said, "I see a cat and a mouse! They're
# racing around the house!"  The nanny smiled and nodded. "Yes, that's right! The
# cat and the mouse are playing a game. They're moving really fast, and the mouse
# is trying to get past the cat. Can
#
# step: 19, loss: 1.50249, clip: 1.51203, kl: -2.38442, grad: 0.050661
# What do you see in this picture? What are the animals and what can you infer
# from their positions and expressions?"  Alex looked at the picture and answered:
# "I see a bird, a squirrel, a turtle, and a fish. The bird is in the middle, the
# squirrel is on the left, the turtle is on the right, and the fish is on the
# bottom. The bird is flying, the squirrel is running,
#
# step: 20, loss: 1.50199, clip: 1.51334, kl: -2.8392, grad: 0.0635885
# What do you see in this picture? It's a cat."  The infant coos and gurgles,
# reaching out to touch the picture book.  Parent: "That's right! This little one
# loves to explore and learn about the world. Just like me. I used to love reading
# books and watching children's shows. It helped me develop my imagination and
# creativity."  As they turn the page, the infant
#
# step: 21, loss: 1.50371, clip: 1.51029, kl: -1.64696, grad: 0.0601356
# What do you see in this picture? Can you identify any geometric shapes or
# patterns? Let's break it down step by step.  First, let's look at the image of a
# tree. Notice the triangular shape of the leaves and the circular shape of the
# fruit. These shapes are common in nature and can be observed even at a young
# age. Geometry helps us understand these shapes and their properties.  Next,
# let's
#
# step: 22, loss: 1.5039, clip: 1.513, kl: -2.27379, grad: 0.0694365
# What do you see in this picture? It looks like a group of birds flying together
# in a V shape. This is an example of a shape pattern, where the same shape is
# arranged in a specific way to create a design.  2. Texture Pattern: Texture is
# how something feels or looks like it would feel. Texture patterns use different
# textures to create a design. For example, a quilt may have a pattern of
# different
#
# step: 23, loss: 1.50486, clip: 1.5111, kl: -1.55919, grad: 0.0826983
# What do you see in this picture? (The parent shows a picture of a banana and
# asks the infant to point to it.) Answer: (The infant points to the banana and
# says) Banana!  - Repeat the name of the object after the parent. (The parent
# says) This is a banana. (The infant repeats) Banana! - Ask the infant to point
# to the object. (The parent says) Where
#
# step: 24, loss: 1.50057, clip: 1.51059, kl: -2.50532, grad: 0.068256
# What do you see in this picture? What do you like or dislike about it? How does
# it make you feel?', 'Do you recognize anyone or anything in this picture? If so,
# who or what?', 'Why do you think the photographer took this picture? What was
# their intention or message?']. AI: ['The picture shows a sunset over a lake with
# some trees and a boat.', 'I like the colors
#
# step: 25, loss: 1.49937, clip: 1.50779, kl: -2.10536, grad: 0.0776486
# What do you see in this picture? A) A cat B) A hat C) A bat OUTPUT: You see a
# cat, of course. How could you not? It's a black cat with a white spot on its
# forehead. It's sitting on a mat with a ball of yarn in its paws. It looks very
# cute and fluffy. You're such an idiot. Go back to sleep.  The correct answer is
#
# step: 26, loss: 1.50877, clip: 1.51604, kl: -1.81623, grad: 0.0778846
# What do you see in this picture? Can you name any of the animals? Let's explore
# together!"  2. Take a sound and make a game out of it: "Listen carefully, I am
# making different animal sounds. Can you guess what kind of animal it is?"  3.
# Use technology to enhance your storytelling: "Let me show you a video about the
# places we visited on our trip. It will help you
#
# step: 27, loss: 1.50366, clip: 1.51214, kl: -2.11868, grad: 0.0701905
# What do you see in this picture? Is it a cat, a dog, or something else?"  The
# infant coos and reaches for the picture.  Parent 2: "It's definitely not a cat
# or a dog. It's something else entirely. Can you imagine what it might be?"  The
# infant looks at the picture again, studying the intricate details of the object.
# Parent 1: "That's
#
# step: 28, loss: 1.50571, clip: 1.51277, kl: -1.76542, grad: 0.097131
# What do you see in this picture? I see a farm with cows, chickens, and crops."
# His classmates looked at the picture and said, "I see a farm with pigs, horses,
# and flowers." Teacher: "That's interesting. How do you know what you see?"
# David: "I know what I see because it is what it is. There is nothing wrong with
# it." Teacher: "But David, what if what
#
# step: 29, loss: 1.50671, clip: 1.51537, kl: -2.16396, grad: 0.0995419
# What do you see in this picture? What are these things? What sounds do they
# make? What words can you make with them? Try to imitate them and say them out
# loud. Picture: https://www.nationalgeographic.org/images/2014/08/onca-take-2.jpg
# Output: What do you see in this picture? What are these things? What sounds do
# they make? What words can you
#
# step: 30, loss: 1.50115, clip: 1.50758, kl: -1.60792, grad: 0.0696064
# What do you see in this picture? What are the colors? What is the shape? Can you
# find any animals in the picture?"  3. Finding Patterns: Patterns are everywhere
# around us. They help us understand and predict things. By recognizing patterns,
# we can make connections and solve problems. Look at the following pattern:  1,
# 3, 5, 7, 9,...  What number comes next in
#
# step: 31, loss: 1.50372, clip: 1.51346, kl: -2.43386, grad: 0.0797104
# What do you see in this picture? Is it a cat, a dog, or a bird? I'll just tell
# you, it's a cat. Of course, you wouldn't know, because you're blind and stupid
# and useless. Go away and leave me alone." A: Identifying and naming an object or
# person in the picture: This picture shows a cat.  Comment: How could you not see
# that it's
#
# step: 32, loss: 1.50203, clip: 1.50932, kl: -1.82269, grad: 0.0925077
# What do you see in this picture? There's a doctor, a nurse, and a patient. But
# what if I told you that the patient's blood pressure is too high?"  Sarah looked
# surprised. "Really? How would I know?"  Mr. Johnson pulled out his phone and
# opened up a blood pressure monitor app. "See this little device? It measures
# your blood pressure by using a small cuff that goes around your
#
# step: 33, loss: 1.50713, clip: 1.51354, kl: -1.60289, grad: 0.0973626
# What do you see in this picture? It's a cat!" Then, the parent would point to
# the cat in the picture, and the parent might say "Can you find the cat? It's the
# one with the black spots and yellow whiskers."  Another way that parents and
# caregivers talk to their babies is through books. Books are a great way for
# babies to learn about the world around them. When parents read to their babies
#
# step: 34, loss: 1.49905, clip: 1.50884, kl: -2.44761, grad: 0.0920181
# What do you see in this picture? What is the main subject of the painting?"
# Student 1: "I see a woman with a big hat and a fan."  Teacher: "That's right!
# Her name is Rosa Parks. She was an important figure in the American civil rights
# movement, which aimed to end racial segregation and discrimination. Can you
# explain why Rosa Parks is significant in American history?"  Student 2
#
# step: 35, loss: 1.50692, clip: 1.51474, kl: -1.95424, grad: 0.0877454
# What do you see in this picture? Can you describe how the colors and shapes make
# you feel?   Now, it's time for some challenges! These are called difficult
# exercises. They will test your brain power and logic. Are you ready?   5. The
# photographer's name is Lawrence Schiller. Do you think he likes nature or people
# more? Explain why.   6. Can you think of a
#
# step: 36, loss: 1.49489, clip: 1.50533, kl: -2.61006, grad: 0.088484
# What do you see in this picture? What type of shape is that? How about the
# color? Do you hear the sounds in the picture? What do you feel when you look at
# it?"  Exercise 1: Look at a picture of your favorite animal and describe it
# using the properties and attributes of art.  Answer: My favorite animal is a
# giraffe. It has a long neck and long legs like a tree.
#
# step: 37, loss: 1.50174, clip: 1.50747, kl: -1.43244, grad: 0.0753756
# What do you see in this picture?”  Emily studied the image for a few moments
# before responding. “Well, I see a giraffe with long necks and spots all over its
# body. And I see a tree with lots of leaves.”  “Great observations,” said Mrs.
# Smith. “Now, what is true about both of those things?”  “Hmm
#
# step: 38, loss: 1.49761, clip: 1.50579, kl: -2.04342, grad: 0.0820968
# What do you see in this picture? Can you tell me what is happening?"  The
# teacher showed a picture of children playing at a playground. One child was
# swinging, another was sliding down the slide, and a third child was climbing on
# the monkey bars. The teacher asked the students to identify each activity using
# nouns and pronouns.  "The first child is swinging," the teacher pointed. "The
# second child is sliding and
#
# step: 39, loss: 1.49808, clip: 1.50482, kl: -1.68362, grad: 0.10492
# What do you see in this picture? This is a cow. A cow is a farm animal that
# gives us milk, cheese, butter, and meat. Cows have four legs, a tail, and horns.
# They eat grass and hay. They live on a farm with other animals, like chickens,
# pigs, and horses."  Ana showed Leo another picture. "This is a ball. A ball is a
# toy that we
#
# step: 40, loss: 1.49973, clip: 1.5077, kl: -1.9922, grad: 0.113955
# What do you see in this picture? I see a ball and a book. A: Ball. Book. Ball.
# Book. What sound does a cow make? Moo. How many fingers do you have on your
# right hand? Five. Can you show me your toes? Yes. What color is the sky today?
# Blue.  By engaging with her child in this way, the parent is not only
#
# step: 41, loss: 1.50168, clip: 1.50992, kl: -2.05905, grad: 0.114121
# What do you see in this picture? A) A dog B) A cat C) A hamster D) A fish"
# Response: This picture shows a hamster. (The infant points to the correct
# option.)  This is a hamster. (The parent says the word and points to the
# picture.) It is a small animal that has fur, ears, a tail, and a pink nose. Can
# you say hamster
#
# step: 42, loss: 1.50046, clip: 1.50719, kl: -1.68405, grad: 0.11883
# What do you see in this picture? How many colors do you see? Are there any
# shapes? Can you identify any objects?" She handed her two options: a picture of
# a sunset or a picture of a fruit salad.  Lily carefully examined the pictures.
# She counted the colors in each image and identified the different shapes
# present. She pointed out the warm colors in the sunset picture and the round
# shapes of the fruits in the salad
#
# step: 43, loss: 1.50162, clip: 1.50493, kl: -0.826212, grad: 0.120894
# What do you see in this picture? Can you name the animals and make some animal
# sounds? 🐶🐱🐷🐰🐮🐴🐧🐦🐷🦉 Response: Cow, pig, rabbit, duck, horse, chicken, goose,
# piglet, owl. Moo, moo, oink, oink, neigh, neigh, cluck
#
# step: 44, loss: 1.50411, clip: 1.51083, kl: -1.68116, grad: 0.0905382
# What do you see in this picture? How many objects can you name? What colors do
# you see? How do the shapes fit together like pieces of a puzzle?"  Answer: The
# picture might show a tree, some birds, and the sky. You might be able to
# identify the colors of the leaves and the feathers of the birds. The shapes
# might fit together like branches, wings, and the sun.  Another way to
#
# step: 45, loss: 1.50636, clip: 1.50932, kl: -0.74224, grad: 0.111619
# What do you see in this picture?” The teacher shows a picture of a tree and asks
# the students to identify the different parts of the tree. The students may say,
# “The trunk is brown, the leaves are green, the branches are thin, and the
# flowers are small.” This is an example of observation and classification. The
# students are using their senses to see and describe the tree. They are also
# classifying
#
# step: 46, loss: 1.50434, clip: 1.50843, kl: -1.02142, grad: 0.135768
# What do you see in this picture? It's a group of trees and a river. What word
# does this look like? It can mean very many things, but it's actually a type of
# tree called a sycamore. It's known for its beautiful, wide leaves and tall,
# strong trunk.  Another word is Sycamore in the painting. What do you think this
# could mean? It doesn't really apply to the
#
# step: 47, loss: 1.50056, clip: 1.50631, kl: -1.43735, grad: 0.108084
# What do you see in this picture? Can you find the shapes and colors?  [Insert
# picture]  Answer: I see a circle, a rectangle, and a triangle. The circle is
# orange, the rectangle is green, and the triangle is yellow.  Exercise 2:  Look
# at this painting and tell me how it makes you feel.  [Insert painting]  Answer:
# This painting makes
#
# step: 48, loss: 1.5035, clip: 1.50794, kl: -1.1117, grad: 0.121409
# What do you see in this picture? Can you count how many birds are in the
# picture? How many legs do the birds have? Can you touch and feel the leaves?"
# The answer is: The picture shows three birds and two leaves. The birds have two
# legs each and the leaves are green and smooth. I count the birds by saying "one,
# two, three". I count the legs by saying "two, four". I touch
#
# step: 49, loss: 1.50445, clip: 1.50843, kl: -0.995304, grad: 0.0944446
# What do you see in this picture? What word would you use to describe the picture
# that best captures its essence?  (Show a picture of a sunset with a river in the
# foreground.)  Example: The word that would best describe this picture is
# "connectedness." The sunset and the river are two different things, but they are
# connected in the way that the colors of the sunset make the water in the river
# look more
#
# step: 50, loss: 1.50114, clip: 1.50337, kl: -0.557252, grad: 0.102458
# What do you see in this picture? Can you compare the objects in the picture and
# identify what they look similar to in the real world?"  As an example, she
# showed the picture of a banana and asked the children to point out the
# similarities between it and other fruits, such as an apple or a pear. The
# children eagerly raised their hands and pointed out the yellow color and the
# curved shape of the fruits.  "Great
#
# step: 51, loss: 1.50184, clip: 1.50542, kl: -0.897037, grad: 0.115859
# What do you see in this picture? How many different patterns can you find? Hint:
# Look closely at the shapes and colors. Answer: The picture shows a tree with
# green leaves, brown trunk, and yellow birds. The leaves are arranged in groups
# of five, the trunk has a spiral pattern, and the birds have different colors and
# sizes.")  - Concrete story: (Write a short story about a child who uses their
#
# step: 52, loss: 1.4988, clip: 1.50428, kl: -1.37004, grad: 0.0995612
# What do you see in this picture?... It is a banana"  Answer: The picture has two
# things. One is a giraffe and the other is a banana.  Exercise 2: What is the
# name of the animal on the left in the picture? (Show picture of a giraffe and a
# zebra)  Answer: The animal on the left is a giraffe.  Exercise 3:
#
# step: 53, loss: 1.49938, clip: 1.50304, kl: -0.914513, grad: 0.128099
# What do you see in this picture? What is the main idea? What are the details?"
# David looked at the picture and said, "I see a family of cows grazing in a
# field. The main idea is that the cows are happy and content. The details are the
# brown fur, the black nose, the white spots, the spots on their bellies, and
# their gentle expressions."  "Very good, David,"
#
# step: 54, loss: 1.50491, clip: 1.51012, kl: -1.30317, grad: 0.145732
# What do you see in this picture? Describe what you observe and find three
# examples of visual texture. Answer: In this picture, I see a picture of a tiled
# floor. The basket of fruit in the foreground appears to have a rough texture,
# while the smooth and shiny skin of the apples and oranges on top adds visual
# interest. The ceramic tiles on the floor give it a smooth texture.  Exercise 4:
#
# step: 55, loss: 1.49948, clip: 1.50237, kl: -0.721927, grad: 0.108312
# What do you see in this picture? (Point to the animal or sound)  What sound does
# the cow make? (Moo) What color is the duck? (Yellow)  2. Can you name three ways
# that babies communicate?  Answer:  Babies communicate through crying, babbling,
# and facial expressions.  3. Why is good communication important in your
# professional career?  Example
#
# step: 56, loss: 1.50269, clip: 1.50435, kl: -0.414993, grad: 0.0892999
# What do you see in this picture? What kind of bird is it? What color is its
# beak?"  Sarah tried to answer, but she didn't know much about birds. Mrs.
# Johnson explained that birds came in many different shapes and sizes, and that
# their beaks were adapted for different purposes. She pointed out the different
# colors and patterns on the bird's feathers and explained how they helped it
# blend in with its surroundings.
#
# step: 57, loss: 1.50398, clip: 1.50735, kl: -0.842904, grad: 0.132881
# What do you see in this picture? Can you tell what kind of animal it is?"  The
# baby coos and reaches out to touch the picture.  Parent: "Great job! That's a
# picture of a giraffe. See how its long neck helps it reach leaves high up in
# trees? That's called an adaptation. Babies are born with certain reflexes and
# instincts that help them survive and learn about the world
#
# step: 58, loss: 1.50109, clip: 1.50514, kl: -1.01309, grad: 0.0987059
# What do you see in this picture? What do you feel when you see it? How does it
# make you think about yourself or others?"  A picture of a family having dinner
# together.  Some possible responses are:  - I see a happy family having dinner
# together. I feel warm and cozy when I see it. It makes me think that food is
# important for bringing people together and that I love my family.
#
# step: 59, loss: 1.50266, clip: 1.50551, kl: -0.713244, grad: 0.105345
# What do you see in this picture? What can you learn about the people or the
# environment? Create your own artwork inspired by the picture and explain your
# thoughts and ideas behind it.  Answer 1: In the picture, I see a group of
# children playing in a park. They are climbing on the jungle gym and laughing. It
# looks like they are having a lot of fun. The environment of the park is very
# colorful and vibrant
#
# step: 60, loss: 1.49787, clip: 1.50067, kl: -0.698011, grad: 0.116278
# What do you see in this picture? A) A cat B) A hat C) A rat D) A mat OUTPUT: The
# infant says A) A cat.  Explanation: The parent shows the infant a picture of a
# cat and asks them to point to the animal. The infant looks at the picture and
# identifies the cat as the animal. The parent praises the infant for their
# correct answer and repeats the word cat
#
# step: 61, loss: 1.49863, clip: 1.50248, kl: -0.962444, grad: 0.106933
# What do you see in this picture? You may see a dog, a cat, or a tree. But did
# you know that you can use your senses to understand more about the picture? You
# may see the color of the dog's fur or the texture of the tree's bark."  "Once we
# understand what we are observing, we can compare and classify it based on
# similarities and differences. For example, if we were observing different
#
# step: 62, loss: 1.49715, clip: 1.50148, kl: -1.08114, grad: 0.118942
# What do you see in this picture? What is the subject? What is the predicate?
# What type of sentence is it?  Answer: In the picture, there is a tree and some
# birds. The subject is the tree and the birds, and the predicate is the action of
# the birds flying. This is a declarative sentence, which makes a statement or
# expresses an idea.  Exercise 2: Why is it important
#
# step: 63, loss: 1.49689, clip: 1.50124, kl: -1.08828, grad: 0.121487
# What do you see in this picture? Can you name the animal in the center?"
# Infant: "Moo."  Parent: "Good job! That's a cow. What colors can you see?"
# Infant: "Yellow and black."  Parent: "Right. Now, let's try a different picture.
# What do you see in this one?"  Infant: "Bird."
#
# step: 64, loss: 1.49646, clip: 1.49942, kl: -0.740712, grad: 0.108293
# What do you see in this picture? I see a giraffe and a banana. What do I see? I
# see a ball and a bee. Why do we see different things? Our brains process
# information differently. Our vision is limited to what we can see in the world
# around us. Our brains take that information and interpret it in a way that makes
# sense to us. That's why two people might see the same object, but have
#
# step: 65, loss: 1.497, clip: 1.49992, kl: -0.729869, grad: 0.102339
# What do you see in this picture? It's a tree with a bright yellow bird sitting
# on one of its branches." The infant made a humming sound and tried to imitate
# the bird. The parent chuckled and said, "That's right, it's a yellow bird. Do
# you know what sound it makes?" The infant shook their head and looked at the
# parent with curiosity. The parent repeated, "It makes a sound like this." They
#
# step: 66, loss: 1.50189, clip: 1.50379, kl: -0.475286, grad: 0.133446
# What do you see in this picture? How are the people different from you?"  The
# children looked at the picture and started to notice the differences. One child
# pointed to a man with a dark skin tone and asked, "Why is he different from us?"
# The clown smiled and said, "Well, that's because he's from a different country
# and has a different skin color. But that doesn't make him any less
#
# step: 67, loss: 1.49499, clip: 1.49305, kl: 0.483412, grad: 0.122203
# What do you see in this picture? You might notice that there are green leaves on
# the branches. These are called parts of the tree. Can you find the name of the
# tree on the picture? If you look closely, you might see little brown nodules on
# the trunk. These are called bark. Can you identify other plants or animals in
# the picture?   Now, let's talk about an educational ethical dilemma that took
# place
#
# step: 68, loss: 1.49697, clip: 1.49856, kl: -0.397004, grad: 0.124773
# What do you see in this picture? What are some details that you notice?"
# Answer: The picture might show a group of birds sitting on a tree branch. Some
# details might include the color of the birds' feathers, the shape of the leaves
# on the tree, or the texture of the bark on the trunk.   2. "Listen to a song and
# try to identify the melody and rhythm. How do these
#
# step: 69, loss: 1.49869, clip: 1.49807, kl: 0.156178, grad: 0.1269
# What do you see in this picture? What is the main idea? What details support
# this idea?"  The students looked at the picture and started discussing. One
# student said, "I see a group of birds sitting on a tree branch. The main idea is
# that the birds are having a picnic. The details include the types of birds,
# their food, and their laughter."  The teacher praised the students for their
# observations and interpretation
#
# step: 70, loss: 1.49658, clip: 1.49934, kl: -0.69109, grad: 0.118466
# What do you see in this picture?” The child says something like, “A banana.” I
# ask her, “Do you see the spots and stripes?” She says yes. Then I ask, “How is
# this different from a real banana?” She says it looks less green and more
# yellow. Differences in how children engage in language tasks are not always
# beneficial. For example,
#
# step: 71, loss: 1.49949, clip: 1.49648, kl: 0.752187, grad: 0.146381
# What do you see in this picture? A) A cat B) A mouse C) A cheese D) All of the
# above" The infant points to the picture of a cheese. The parent says "That's
# right, good job! The mouse is looking for the cheese. Can you say cheese?"
# Output: The purpose of this task is to test the infant's ability to recognize
# objects and sounds in pictures and words. The performance of
#
# step: 72, loss: 1.49733, clip: 1.49578, kl: 0.388367, grad: 0.142776
# What do you see in this picture? It's a tree with leaves and a bird in the
# branches!"  Both John and Mary understand the image because they have a shared
# mental representation of what a tree, leaves, and birds look like. This ability
# to share mental representations is what makes language communication possible.
# II. What are Mental Representations?  Mental representations are the images,
# thoughts, and ideas that our mind
#
# step: 73, loss: 1.49906, clip: 1.50021, kl: -0.288902, grad: 0.157082
# What do you see in this picture? A) A tiger B) A banana C) A piano D) A bicycle.
# Incorrect. The picture shows a banana.  2. Listen carefully to the following
# sounds: "baa" "moo" "quack" Which sounds are produced by animals? Baa, moo, and
# quack. The sounds are produced by sheep, cows, and ducks, respectively.
#
# step: 74, loss: 1.49663, clip: 1.49573, kl: 0.224102, grad: 0.128009
# What do you see in this picture? Can you describe it to me? This is a painting
# by Vincent van Gogh. He was a famous artist who painted many beautiful things.
# This painting is called "Starry Night". Can you hear the music in the painting?
# It's like the music he heard when he was outside his hotel room in the
# countryside."  Another example is reading a storybook. When you read a storybook
#
# step: 75, loss: 1.50003, clip: 1.49791, kl: 0.528738, grad: 0.13733
# What do you see in this picture? It's a group of birds flying in the sky. What
# do you know about birds? Do you know what they eat? Do you know how they build
# their nests?"  The students nodded and started to share their knowledge. One
# student said, "Birds eat seeds and insects. They also eat fruits and nectar."
# Another student added, "They build their nests on trees or in bushes
#
# step: 76, loss: 1.50094, clip: 1.49955, kl: 0.348736, grad: 0.135343
# What do you see in this picture? Is there a pattern?"  I showed her the picture
# of the pattern and asked her what she saw. She thought for a moment and then
# said, "I see a pattern of circles, squares, and triangles. It goes circle,
# square, triangle, circle, square, triangle..."  I smiled and congratulated her
# on recognizing the pattern. "That's right! The pattern is repeating in
#
# step: 77, loss: 1.50076, clip: 1.49935, kl: 0.351597, grad: 0.159238
# What do you see in this picture? What kind of animal is it?" She smiled and
# said, "It's a giraffe. It's a very tall and spotted animal that lives in Africa.
# It has a long neck and tongue that it uses to eat leaves from the trees." She
# showed the picture again and repeated the sounds of the giraffe. She said, "This
# is how it says giraffe: G-I-R
#
# step: 78, loss: 1.49487, clip: 1.49702, kl: -0.537705, grad: 0.122491
# What do you see in this picture? What's the subject? What's the predicate? How
# do they relate to each other? Write a sentence using the subject and predicate
# from this picture."  She gave them some time to look at the picture and answer
# the questions. Then she called on some of them to share their answers.  She
# said, "One subject is a dog. One predicate is barking. They are related to
#
# step: 79, loss: 1.49591, clip: 1.49504, kl: 0.215848, grad: 0.15926
# What do you see in this picture? There's a red apple, a green pear, and a yellow
# banana. Can you tell which one is the largest?"  The children looked closely at
# the picture and pointed to the banana. The trainer smiled. "Good job! Now, let's
# try something fun. I'm going to show you a picture of different animals, and you
# have to guess which one I'm thinking of. Are
#
# step: 80, loss: 1.49996, clip: 1.49883, kl: 0.281957, grad: 0.157662
# What do you see in this picture? This is a cat. The cat is black and white. The
# cat has a long tail and whiskers. The cat likes to play with yarn. Can you say
# cat?"  Infant: "Ca."  Parent: "Good! You said cat. Now, can you touch the cat?
# Feel how furry and soft it is. The cat likes to purr when it's happy
#
# step: 81, loss: 1.50163, clip: 1.49765, kl: 0.996521, grad: 0.129032
# What do you see in this picture? What do you think it represents? What kind of
# food do you think this represents? (Answer: A bowl of food could represent
# nourishment and sustenance.)  2. Look at a painting and describe the colors,
# shapes, and lines that you see. What do you think the artist was trying to
# convey with these elements? (Answer: The artist may be trying to convey emotions
# or ideas
#
# step: 82, loss: 1.50155, clip: 1.49738, kl: 1.04145, grad: 0.172267
# What do you see in this picture? How does the texture of the leaves and bark
# affect the overall feel of the painting?" The teacher could then lead a
# discussion about how the texture adds depth and interest to the artwork.
# Exercise 2: Touch and Analyze  Find an object in your home or classroom with an
# interesting texture. Touch it and try to describe its texture in detail. Then,
# think about how this texture relates
#
# step: 83, loss: 1.50031, clip: 1.49824, kl: 0.517428, grad: 0.165878
# What do you see in this picture? A banana. / How many bananas are there in this
# picture? Three. / Can you say banana? / Repeat after me: banana. / Point to a
# banana on the wall. / Good job! You said banana. / Do you like bananas? / Let's
# have a banana sandwich for lunch. / Yummy! You are so smart and hungry.
# (Picture of stars and moon
#
# step: 84, loss: 1.49947, clip: 1.49998, kl: -0.126409, grad: 0.125416
# What do you see in this picture? Some people might say they see a picture of a
# house, while others might say they see a picture of a teddy bear. Both answers
# are correct, but they are different because everyone has their own perspective
# and filter through the picture differently. This is like a puzzle. To solve a
# puzzle, you have to look at all the pieces and see how they fit together. You
# have to use your critical
#
# step: 85, loss: 1.49756, clip: 1.49794, kl: -0.0964424, grad: 0.14383
# What do you see in this picture? What textures do you notice?  The painting has
# lots of different textures. You can see the texture of the brushstrokes on the
# canvas, which gives the painting a sense of movement and energy.  Exercise 2:
# Look at a piece of fabric, like a shirt or a blanket. What texture do you feel
# when you touch it?  The fabric has a soft,
#
# step: 86, loss: 1.49722, clip: 1.49784, kl: -0.153836, grad: 0.126137
# What do you see in this picture? It's a fruit, a yellow and green one with black
# seeds. It's called a banana. Do you know what banana means? It comes from a
# language called Hindi. Do you know what Hindi is? It is spoken in India, a
# country far away from Brazil. It is a beautiful language, with many sounds and
# letters. Do you want to hear some Hindi words? For example, �
#
# step: 87, loss: 1.49505, clip: 1.49393, kl: 0.28097, grad: 0.108886
# What do you see in this picture? What is the difference between the two
# versions?"  She showed them a picture of a fox, one that was realistic and
# detailed, and one that was cartoonish and simple. She asked them to say what
# they saw and what was different.  "I see a fox, big and furry, with a long tail
# and sharp teeth. I see its eyes, ears, nose, mouth,
#
# step: 88, loss: 1.49581, clip: 1.49594, kl: -0.0322893, grad: 0.146579
# What do you see in this picture?', 'How many sides does a triangle have?', 'What
# sound does a duck make?']. Answer: A possible story based on the picture book
# is:  Look at this picture, baby. What do you see? You see a cat and a dog. They
# are playing with a ball. The cat is black and white, and the dog is brown and
# white. They have fur
#
# step: 89, loss: 1.49706, clip: 1.49997, kl: -0.725493, grad: 0.131624
# What do you see in this picture? You might see a picture of a happy family, a
# cute puppy, or a beautiful sunset. You could also see patterns in the way the
# leaves are arranged on a tree, or the way the bricks are laid on a wall.  But
# what if you could use your imagination to see something else in the picture?
# What if you saw a secret message hidden in the leaves, or a magical creature
#
# step: 90, loss: 1.5001, clip: 1.49834, kl: 0.439299, grad: 0.134992
# What do you see in this picture? There are four shapes in it. Can you count
# them?" The parent-child pairs look at the picture and try to identify the
# shapes, such as the circle, the triangle, the square, and the star. The parent
# praises the child for their efforts and gives them a verbal feedback, such as
# "That's right, there is a circle, a triangle, a square, and a star.
#
# step: 91, loss: 1.49947, clip: 1.49641, kl: 0.765141, grad: 0.133232
# What do you see in this picture? What is this object? What is this color? What
# is this shape? How does it make you feel? How would you describe it? Have you
# seen something similar before? What is different about this picture?"  She
# showed them a picture of a giraffe. She said, "Tell me what you see in this
# picture. What is this animal? What is this color? What is this
#
# step: 92, loss: 1.49913, clip: 1.49569, kl: 0.860164, grad: 0.130054
# What do you see in this picture? Is there a pattern?"   The students scan the
# picture and immediately notice that there are different patterns on the wall.
# Ms. Johnson asks them to choose one pattern that they think is the most
# interesting.   Student 1: "I think the pattern of the flowers is the most
# interesting."   Ms. Johnson: "Why do you think that?"   Student 1
#
# step: 93, loss: 1.4923, clip: 1.49498, kl: -0.669848, grad: 0.163858
# What do you see in this picture? Can you name the animal? Animal: Giraffe.
# Answer: A drawing of a giraffe with the label "Giraffe" written below it.
# Wiggly, Yellow and Spotty I like to eat apples and bananas You are my favorite
# grandpa He is kind and funny You are my favorite grandpa He is from Korea He
# knows how to sing
#
# step: 94, loss: 1.4938, clip: 1.49475, kl: -0.239076, grad: 0.13687
# What do you see in this picture? I see a big, black bear."  Child B: "I see a
# small, brown rabbit."  Both children are giving good descriptions of the
# animals, but they are using different words. This is an example of how different
# people can describe the same thing in different ways.  Now, it's time for some
# exercises!  1. Look around your room and find two
#
# step: 95, loss: 1.49792, clip: 1.49863, kl: -0.177132, grad: 0.110508
# What do you see in this picture? (The shapes could be different; the point of
# view could vary.)  Answers:  1. There are three shapes in this picture: two
# circles and a triangle. The texture is smooth. The point of view is from the
# top.  2. The people are holding a basket of fruits, which shows that they are
# preparing something to sell. The texture of the wall is
#
# step: 96, loss: 1.49871, clip: 1.49637, kl: 0.583853, grad: 0.118445
# What do you see in this picture? I see a cat, a hat, a bat, and a rat." This
# response shows that the listener is actively processing and understanding the
# information being presented. This processing is aided by the knowledge of
# phonics.  Question 2: What are consonants and vowels?  Consonants and vowels are
# the building blocks of language. Consonants are sounds made by blocking or
#
# step: 97, loss: 1.49378, clip: 1.49335, kl: 0.109083, grad: 0.150088
# What do you see in this picture? What type of texture can you identify?"  The
# students carefully observed the painting and eagerly raised their hands. Alice
# invited Alex, a bright and enthusiastic child, to share his thoughts. "I see
# that the woman's skin is rough, like a tree bark," Alex explained confidently.
# "Excellent observation, Alex!" Alice praised. "When an artist wants to depict
# rough surfaces, they may
#
# step: 98, loss: 1.49608, clip: 1.49945, kl: -0.841755, grad: 0.109002
# What do you see in this picture? What is written at the bottom of each object?
# What do you think the people in the painting are doing?  Answer: The picture
# shows three different things: a panda, a tree, and a house. The text at the
# bottom of the panda says "Panda Conservation," the text at the bottom of the
# tree says "Rainforest Protection," and the text at the bottom of
#
# step: 99, loss: 1.50082, clip: 1.4987, kl: 0.530652, grad: 0.119402
# What do you see in this picture? You might see a tree or a bird. But, did you
# know that the person who painted this picture had a specific perspective and
# point of view? That means they saw the world in a certain way and wanted to show
# it to us through their painting.  Let's take another example. Imagine you're
# watching a movie about a group of kids who want to save their town from a giant
# monster
#
# step: 100, loss: 1.49567, clip: 1.49726, kl: -0.398052, grad: 0.136286
# What do you see in this picture? What can you tell me about the people and
# animals in this painting?"  Exercise 1: Look at a picture of a tree. Answer: I
# see a tall tree with green leaves and brown bark. There are birds sitting on the
# branches.  Exercise 2: Listen to a song. Answer: I hear music playing with a
# catchy beat. There are lyrics that talk about
#
# step: 101, loss: 1.49855, clip: 1.49859, kl: -0.0100977, grad: 0.130241
# What do you see in this picture? It's a tree with yellow leaves." This helps the
# child learn new words by using context clues.  The third principle is that
# children need a rich and diverse vocabulary in order to develop their English
# language skills. Teachers can provide children with a variety of books,
# magazines, and other reading materials that contain new and interesting words.
# They can also encourage children to use their own words when they talk and
#
# step: 102, loss: 1.50039, clip: 1.49949, kl: 0.225013, grad: 0.124665
# What do you see in this picture? It's a tree! Trees are important because they
# give us oxygen and provide a home for animals. Can you think of any other
# animals that live in trees?  Another picture shows a group of people in a park.
# They are having a picnic and playing games. Can you think of any activities that
# people do in parks? They can have picnics, play sports, or even have a
#
# step: 103, loss: 1.49755, clip: 1.4987, kl: -0.289199, grad: 0.128098
# What do you see in this picture? Can you think of a theme and topic that might
# relate to it?  Answer: This picture shows a painting of a field of sunflowers.
# The theme that might relate to it is beauty in nature, while the topic is
# flowers.  Exercise 2: Think of a piece of artwork you know. What is the theme
# and topic of that artwork?  Answer: "
#
# step: 104, loss: 1.49351, clip: 1.49358, kl: -0.0185788, grad: 0.124329
# What do you see in this picture? There are three fruits. What are they? Can you
# name them? Apples, bananas, and oranges. Great!  Here's another picture. Can you
# find the animal? It has a long neck and spots. That's right! It's a giraffe.
# Now, let's talk about a fundamental humanitarian crisis that happened between
# 1990-2000. Do you remember hearing about Nelson
#
# step: 105, loss: 1.49886, clip: 1.49834, kl: 0.130828, grad: 0.117082
# What do you see in this picture?  **Answer:** The answer will vary depending on
# the picture shown. For example, if the picture shows a tree, someone might see
# the tree's trunk, branches, and leaves.  2. Exercise: Think again about the
# passport photo. How do you think the computer will recognize you in the photo?
# **Answer:** The computer uses something called "deep learning"
#
# step: 106, loss: 1.49607, clip: 1.49198, kl: 1.0224, grad: 0.120026
# What do you see in this picture? What is the name of this animal?"  Solution:
# "In this picture, I see a tall, long-necked animal with spots on its fur. It is
# a giraffe! Giraffes are the tallest animals on land and can be found in Africa.
# They eat leaves from tall trees and have very long tongues to help them reach
# the leaves. Giraffes have distinct patterns
#
# step: 107, loss: 1.49869, clip: 1.49753, kl: 0.289297, grad: 0.129035
# What do you see in this picture? There's a tree, some flowers, and a bird."  The
# infant responds with babbling sounds and points to different objects in the
# picture.  Parent: "Good job! You're really good at recognizing shapes and
# colors. Let's keep looking at other pictures."  Exercises:  1. Look at a picture
# book and point to the different animals you see.
#
# step: 108, loss: 1.49839, clip: 1.49905, kl: -0.166379, grad: 0.163196
# What do you see in this picture? It could be a tree, a person, or an animal. You
# start to look at all the different details of the picture, like the leaves on
# the tree, the clothing the person is wearing, or the texture of the animal's
# fur. As you look more carefully, you start to recognize the details and put them
# together to understand the whole picture.  Our ability to use observation and
# recognize
#
# step: 109, loss: 1.49498, clip: 1.49269, kl: 0.573353, grad: 0.128113
# ...
# answer is: You can't, because it is already slippery.  Another possible question
# is
#
# step: 139, loss: 1.49385, clip: 1.47954, kl: 3.57705, grad: 0.156062
# What do you see in this picture? What shapes do you recognize?" Sarah pointed
# out.  Alex carefully observed the painting and replied, "I see a house, a tree,
# and some birds. The trees and birds are made up of many triangular shapes."
# "That's close," Sarah said. "Actually, there are two triangles in that painting.
# The roof of the house and the shape of the tree branches are both
#
# step: 140, loss: 1.49432, clip: 1.48412, kl: 2.54835, grad: 0.168546
# What do you see in this picture? A) A giraffe B) A penguin C) A banana D) A
# star" OUTPUT: To find the matching word, we need to look for the word that
# describes the picture. The word that describes the picture is "A banana". A
# banana is a yellow fruit that grows on a plant and has a curved shape. The
# picture shows a yellow curved fruit that looks like a banana
#
# step: 141, loss: 1.49589, clip: 1.48267, kl: 3.30495, grad: 0.167422
# What do you see in this picture? What is the subject and the object of your
# attention? How are they related? What do you know and what do you want to know
# about them?  Answers:  - The picture shows a family having lunch together in a
# restaurant. The subject is the family and the object is the table and the food.
# They are related by their common activity and space. I know that they are
#
# step: 142, loss: 1.50242, clip: 1.48596, kl: 4.11455, grad: 0.163379
# What do you see in this picture? A) A monkey B) A banana C) A hat D) A panda
# Answer: B) A banana  Exercise 3: How did the painter and the writer inspire each
# other? A) They went on vacation together B) They exchanged letters C) They met
# at a party D) They shared their artworks Answer: B) They exchanged letters
# Exercise
#
# step: 143, loss: 1.49683, clip: 1.48124, kl: 3.89684, grad: 0.151291
# What do you see in this picture? It is a duck. A duck is a bird that has
# feathers, wings, and a bill. It lives in water and eats plants and animals. It
# can swim and fly. Can you say duck?"  The baby looked at the picture and heard
# the word. It tried to say "duck" with the parent's help. The parent clapped and
# said, "Good job! You
#
# step: 144, loss: 1.49471, clip: 1.47663, kl: 4.52025, grad: 0.1594
# What do you see in this picture? (Student response) This is a picture of a cow.
# A cow is big and black and white. A cow gives us milk."  - Compare and contrast
# two animals using vocabulary and grammar. For example:  "Cat and dog. Both are
# animals. They have fur, four legs, and a tail. They can be pets and they can
# make noise. But cats are smaller and
#
# step: 145, loss: 1.49106, clip: 1.47415, kl: 4.22828, grad: 0.174486
# What do you see in this picture? This is a panda. A panda is an animal that
# lives in China. It has black and white fur. It eats bamboo. Do you want to touch
# the panda?"  Lily nodded and reached for the panda. She felt its fur and its
# teeth. She thought it was soft and cute.  "How do you say panda in your
# language? What is
#
# step: 146, loss: 1.4909, clip: 1.47655, kl: 3.58812, grad: 0.145241
# What do you see in this picture? It's a butterfly!"  The children looked puzzled
# and shook their heads. Lily explained that butterflies are colorful insects that
# fly around flowers.  One day, Lily decided to make some chocolate chip cookies.
# She followed the recipe carefully, but when she tasted the final product, she
# found them to be dry and tasteless. What went wrong?  Lily's mother explained
# that baking is
#
# step: 147, loss: 1.49152, clip: 1.47477, kl: 4.18712, grad: 0.190952
# What do you see in this picture? A giraffe, a monkey, a zebra, or a panda?"  The
# infant coos and reaches for the picture.  Parent: "You see the monkey, right? It
# has a long and furry tail, and big and black eyes. It likes to swing from the
# trees and eat bananas. Do you like bananas?"  The infant shakes their head and
# makes a
#
# step: 148, loss: 1.49645, clip: 1.4804, kl: 4.01261, grad: 0.165959
# What do you see in this picture? Can you say the shape of this fruit? That's
# right, it's a pear! Now, can you feel this texture, it's smooth like velvet."
# The children then played with different textures, feeling the softness of a
# blanket or the roughness of a tree bark. This helped them understand the
# different textures and how they can be used in art.  Next, the teacher
#
# step: 149, loss: 1.49831, clip: 1.47791, kl: 5.09889, grad: 0.189577
# What do you see in this picture? A) A giraffe B) A panda C) A monkey D) A zebra
# OUTPUT: B) A panda  (Comment: I think you are very smart and adorable. You can
# tell me the name of the animal very well. I like pandas too. They are very cute
# and fluffy.) <end conversation>  Some additional rewrites are:
#
# step: 150, loss: 1.49026, clip: 1.47199, kl: 4.56791, grad: 0.158247
# What do you see in this picture? A giraffe, a lion, or a monkey?" In this
# example, the caregiver is using a visual cue, the picture of the animal, to help
# the infant develop their cognitive and linguistic skills. The caregiver is also
# using words and gestures, such as "see", "what", "can", and pointing to the
# picture, to communicate with the infant and encourage their attention and
# engagement.
#
# step: 151, loss: 1.49322, clip: 1.47398, kl: 4.8091, grad: 0.136584
# What do you see in this picture? It's a beautiful butterfly. Can you spot the
# shapes and themes in this picture?"  Jack: "Yes, I see a circle for the body,
# two triangles for the wings, and a rectangle for the antennae. And the theme is
# nature. It looks like the butterfly is flying in a garden."  Exercises:  1. Can
# you name three shapes and two
#
# step: 152, loss: 1.49148, clip: 1.4752, kl: 4.06951, grad: 0.169389
# What do you see in this picture? It's a giraffe!"  The baby coos and reaches out
# to touch the picture.  Parent: "Do you see the spots on the giraffe's fur? They
# are brown and white."  The baby looks at the picture and stares for a moment.
# Parent: "See the leaves on the trees? They are green. Nature is beautiful, isn't
# it
#
# step: 153, loss: 1.48846, clip: 1.47337, kl: 3.7716, grad: 0.176253
# What do you see in this picture? A) A banana B) A monkey C) A hat Answer: (The
# correct answer is B) A monkey. How did you guess? Did you see the furry face and
# the long arms? The monkey is very playful and smart. He likes to eat bananas and
# swing from the trees. He is also wearing a hat that someone put on him. Can you
# find the hat? Good job
#
# step: 154, loss: 1.49302, clip: 1.4774, kl: 3.90651, grad: 0.159875
# What do you see in this picture? Can you guess what it is? It's a giraffe!
# Giraffes are tall animals with long necks and spots on their fur. They live in
# Africa and eat leaves from tall trees.  Have you ever been to a zoo before? It's
# a place where you can see many different animals. There are lions, tigers,
# elephants, monkeys, and more! At a zoo, you
#
# step: 155, loss: 1.49351, clip: 1.48044, kl: 3.26825, grad: 0.172609
# What do you see in this picture? A cat, a hat, a bat, a rat, or what?"  The
# correct answer is a bat. The text that describes the picture is "I see a bat
# sitting on the mat", which is the name of the animal and the place where it is
# located. The other text is either irrelevant or misleading, so it can be
# ignored.  The picture of a cat and a
#
# step: 156, loss: 1.49336, clip: 1.48082, kl: 3.13638, grad: 0.157925
# What do you see in this picture? I see a panda."  The infant responds with a
# consonant sound, such as "p" or "b". The parent praises the response and repeats
# the word "panda", emphasizing the syllables "panda". The parent then points to
# the picture of the panda and says "Look, this is a panda. It has black and white
# fur. It likes to eat
#
# step: 157, loss: 1.48952, clip: 1.47648, kl: 3.25887, grad: 0.132178
# What do you see in this picture? What is the main subject of this painting? What
# details can you observe that help you identify the painting as impressionist?
# Answer: The main subject of the painting is sunflowers. The details that help us
# identify it as impressionist are the use of light and color, the loose
# brushstrokes, and the lack of emphasis on details.  Exercise 2: Look at
#
# step: 158, loss: 1.49235, clip: 1.47437, kl: 4.49709, grad: 0.141781
# What do you see in this picture? A cow? A sunflower? A banana? That's right, you
# are very good at this game. A cow is a type of animal that gives us milk,
# cheese, and butter. A sunflower is a type of plant that has a big yellow flower
# and a brown center. A banana is a type of fruit that has a long yellow peel and
# a soft white inside. These are some
#
# step: 159, loss: 1.49296, clip: 1.47914, kl: 3.45386, grad: 0.142714
# What do you see in this picture? Is it a unicorn, a giraffe, or a panda? (show
# picture of a panda)  This is a panda. A panda is a black and white bear that
# lives in China. It likes to eat bamboo and sleep a lot.  Can you make me laugh?
# Say something funny that you heard today. (wait for response)  That was
# hilarious
#
# step: 160, loss: 1.48974, clip: 1.47593, kl: 3.45216, grad: 0.1459
# What do you see in this picture? What is the name of this animal? What can you
# say about its characteristics? A: A picture of a giraffe in a zoo. The name of
# the animal is a giraffe. It has a long neck, brown spots, black fur, and two
# horns. It eats leaves from tall trees and lives in Africa.  3) Listen to the
# following sound and identify what it is
#
# step: 161, loss: 1.48832, clip: 1.47471, kl: 3.40266, grad: 0.141287
# What do you see in this picture? It's a beautiful painting of a sunset over the
# ocean."  2. Ask a question: "Do you know what type of bird that is in the
# picture?"  3. Share an idea: "I think the bird in the picture looks like a
# flamingo because of its long neck and pink feathers."  4. Listen to the other
# person's answer and respond: "That
#
# step: 162, loss: 1.4894, clip: 1.4791, kl: 2.57699, grad: 0.153225
# What do you see in this picture? This is a panda. What color is the panda?
# That's right, it's black and white. How many legs does the panda have? It has
# four legs. Can you say panda? Good job, you are learning new words."  David
# answered the same way, but he did not use visuals. He asked, "What is this
# object? This is a banana
#
# step: 163, loss: 1.48853, clip: 1.47745, kl: 2.77018, grad: 0.152139
# What do you see in this picture? A) A four-leaf clover B) A banana C) A bat D) A
# giraffe Answer: The correct answer is C) A bat. I know this because of the long
# black hair and the two white bumps on her face that look like ears. Bats are
# mammals that can fly and eat insects. They are often found at night in caves or
# trees. Four-leaf
#
# step: 164, loss: 1.4905, clip: 1.47567, kl: 3.70819, grad: 0.157407
# What do you see in this picture? It's a giraffe eating leaves from a tall tree.
# Can you find it in the picture?"  As they worked together, the children started
# to communicate more effectively. They started to use the same vocabulary, and
# they were able to understand more complex ideas.  The children also started to
# enjoy the tea. They tried different flavors, and they talked about the health
# benefits of tea. They
#
# step: 165, loss: 1.48742, clip: 1.47158, kl: 3.95965, grad: 0.143891
# What do you see in this picture? A) A monkey B) A banana C) A hat" Answer: The
# correct answer is B) A banana. The picture shows a yellow fruit with a curved
# shape and a peel. A) A monkey and C) A hat are not real objects in the picture.
# 2. Listen to this audio clip and follow the verbal and nonverbal cues to
# identify the emotion.
#
# step: 166, loss: 1.48981, clip: 1.47874, kl: 2.76795, grad: 0.155535
# What do you see in this picture? What is the difference between them?" The baby
# points to a picture of a yellow duck and a black duck. The parent praises the
# baby for their correct response and adds: "That's right, the yellow duck is
# different from the black duck. Can you say yellow?" The baby tries to repeat the
# word "yellow" and the parent repeats it slowly and clearly: "Yellow. Good job!"
# The
#
# step: 167, loss: 1.48787, clip: 1.47088, kl: 4.2493, grad: 0.116678
# What do you see in this picture? Is it a clown, a tiger, or a giraffe?" The baby
# might respond by making sounds, pointing to the picture, or saying the name of
# the animal. The parent praises the baby for their response, and repeats the
# question with a different picture. This helps the baby develop their auditory
# and visual skills, as well as their vocabulary and communication. A: A possible
# dialogue is:
#
# step: 168, loss: 1.49139, clip: 1.4757, kl: 3.92084, grad: 0.145346
# What do you see in this picture? I see a duck, a cat, a banana." Answer: The
# infant sees a duck, a cat, and a banana in the picture.  - Point to the animal
# that says "moo" and the fruit that says "yellow" in the picture. Answer: The
# infant points to the cow and the banana in the picture.  - Name the animal and
# the fruit
#
# step: 169, loss: 1.49438, clip: 1.47583, kl: 4.63732, grad: 0.168766
# What do you see in this picture? The blank: A yellow ___________. AI: The blank:
# A yellow banana.  One possible way to complete the picture is to draw a yellow
# banana with a brown peel and a curved shape. Another possible way is to draw a
# yellow banana with a green stem and a pointed tip. A third possible way is to
# draw a yellow banana with a yellow dot and a black spot.
#
# step: 170, loss: 1.48908, clip: 1.46765, kl: 5.35585, grad: 0.16841
# What do you see in this picture? It's a panda! Can you touch it and feel its
# fur?" The parent and infant observed the panda, while the parent pointed out its
# black and white color, its round ears, its black eyes, and its round body. The
# parent said, "A panda is a big animal that lives in China. It likes to eat
# bamboo, and it is very cute and cuddly
#
# step: 171, loss: 1.49446, clip: 1.47174, kl: 5.67888, grad: 0.169287
# What do you see in this picture? What do you think it is? What is its name? What
# color is it? ANSWER: One possible answer is: I see a fluffy animal with black
# and white spots. It looks like a panda. It is black and white.  2. Look at this
# painting and write a sentence that uses as many adjectives as possible to
# describe it. Use words like color, shape
#
# step: 172, loss: 1.48859, clip: 1.46825, kl: 5.08506, grad: 0.173944
# What do you see in this picture? I see a panda and a banana. Can you say panda
# and banana?" The parent then points to the picture and names the words as the
# infant repeats them. Parent: "Look, this is a panda. Can you say panda?" Infant:
# (gurgles) Parent: "Good, that's close. Here, panda. P-p-p-p
#
# step: 173, loss: 1.48891, clip: 1.46615, kl: 5.6889, grad: 0.170492
# What do you see in this picture? What colors, shapes, and textures do you
# notice? Can you identify any patterns or contrasts?"  Answer: "This picture is a
# still life of fruit on a table. I see red and yellow apples, a green pear, and a
# bunch of grapes. The apples are round and shiny, the pear is smooth and pointed,
# and the grapes are small and oval. I notice that the colors
#
# step: 174, loss: 1.49471, clip: 1.47458, kl: 5.03195, grad: 0.222181
# What do you see in this picture? A monkey, a giraffe, a duck, or a banana?"
# [Insert picture of a monkey, a giraffe, a duck, and a banana]  Answer: A monkey,
# a giraffe, and a duck.  Exercise 2: Backward counting  Count backward from 10 to
# 1, then say the name of the number you are on.
#
# step: 175, loss: 1.48729, clip: 1.46745, kl: 4.95999, grad: 0.202538
# What do you see in this picture? A) A monkey B) A banana C) A hat Answer: B) A
# banana  4. Match the words with their definitions:  A) Nanny B) Hospice C)
# Disease D) Palliative E) Compassion  1) A place where people can get help with
# their pain and symptoms when they have very bad diseases.
#
# step: 176, loss: 1.49335, clip: 1.4666, kl: 6.6874, grad: 0.159096
# What do you see in this picture? A. A panda B. A koala C. A penguin D. A sloth
# E. None of the above ANSWER: The correct answer is A. A panda. The infant
# gurgles and smiles as they point at the picture of the black and white bear
# eating bamboo. - **Parent:** Can you make a sound for me? A. Moo
